# %% [markdown]
# <a href="https://colab.research.google.com/github/PauloJsReact/Cadastro_pyton/blob/main/cadatro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#criar banco de dados
import json
import os

os.makedirs('src/banco_de_dados', exist_ok=True)

# %%
#Salvar usuário

import random
import json
import os

users=[]
data= []
name = "";
email="";
id ="";


print("Cadastre o nome de usuário");
name = input()
print("Insira o e-mail")
email=input()
id = random.randint(1,100)
users=[id,name,email]
print("Usuário cadastrado",users)

data = {"Usuários": users}
print(data)


with open('src/banco_de_dados/data.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, indent=4, ensure_ascii=False)
print("Usuário cadastrado com sucesso")
# Out:
# Cadastre o nome de usuário
# Piter
# Insira o e-mail
# novoemail@my.co.
# Usuário cadastrado [42, 'Piter ', 'novoemail@my.co.']
# {'Usuários': [42, 'Piter ', 'novoemail@my.co.']}
# Usuário cadastrado com sucesso

# %%
#carregar usuario
import json
data_loand =[]

with open('src/banco_de_dados/data.json' ,'r', encoding='utf-8') as f:
 data_loand = json.load(f)
print(data_loand)
# Out:
# {'Usuários': [42, 'Piter ', 'novoemail@my.co.']}
